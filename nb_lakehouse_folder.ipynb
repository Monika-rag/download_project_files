-- %%
CREATE TABLE IF NOT EXISTS dbo.md_ingestion_config (
    ingestion_config_id STRING,
    ingestion_name STRING,

    source_type STRING,
    connection_name STRING,
    source_object_name STRING,
    source_folder_path STRING,
    source_file_pattern STRING,

    load_type STRING,
    watermark_column STRING,
    watermark_value STRING,

    target_path STRING,
    target_file_name STRING,
    target_format STRING,
    write_mode STRING,

    schedule_group STRING,
    execution_sequence INT,
    active_flag BOOLEAN,

    created_at TIMESTAMP,
    updated_at TIMESTAMP,
    expected_file_count INT,
    move_after_copy STRING,
    recursive STRING,
    fail_if_no_files STRING
)
USING DELTA;
-- Out:
-- StatementMeta(, 69a8fcaf-e407-4c6a-9a0c-4860307a5aba, 12, Finished, Available, Finished, False)
-- <Spark SQL result set with 0 rows and 0 fields>

-- %%
INSERT INTO dbo.md_ingestion_config
(
    ingestion_config_id, ingestion_name, source_type, connection_name, source_object_name, source_folder_path, source_file_pattern, load_type, watermark_column, watermark_value, target_path, target_file_name, target_format, write_mode, schedule_group, execution_sequence, active_flag, created_at, updated_at, expected_file_count, move_after_copy, recursive, fail_if_no_files
)
VALUES
('CFG_ONELAKE_TO_SFTP_001', 'Weekly OneLake to SFTP Upload', 'FunctionApp', 'func-crm-mmhci-tst-ae-01', 'OneLakeToSFTP', 'Files/processed/Dataverse', '*.csv', 'FULL', NULL, NULL, 'inbox', NULL, '', '', 'WEEKLY', 14, true, current_timestamp(),  current_timestamp(), 14, 'false', 'false', 'false'),
('CFG_PRACTITIONER_PREFERENCES_001', 'Practitioner Preferences Load', 'Dataverse', 'dataverse_connection', 'Practitionerpreferences', 'Files/raw/Dataverse', '*.csv', 'FULL', 'NULL', 'NULL', 'Files/processed/Dataverse', 'Practitionerpreferences.csv', 'csv', 'overwrite', 'WEEKLY', 7, true,  current_timestamp(),  current_timestamp(), NULL, NULL, NULL, NULL),
('CFG_QUESTIONNAIRE_RESPONSE_001', 'Questionnaire Response Load', 'Dataverse', 'dataverse_connection', 'Questionnaireresponse', 'Files/raw/Dataverse', '*.csv', 'FULL', 'NULL', 'NULL', 'Files/processed/Dataverse', 'Questionnaireresponse.csv', 'csv', 'overwrite', 'WEEKLY', 11, true,  current_timestamp(),  current_timestamp(), NULL, NULL, NULL, NULL),
('CFG_QUESTIONNAIRE_MATERIAL_001', 'Questionnaire Material Load', 'Dataverse', 'dataverse_connection', 'Questionnairematerial', 'Files/raw/Dataverse', '*.csv', 'FULL', 'NULL', 'NULL', 'Files/processed/Dataverse', 'Questionnairematerial.csv', 'csv', 'overwrite', 'WEEKLY', 9, true,  current_timestamp(),  current_timestamp(), NULL, NULL, NULL, NULL),
('CFG_QUESTIONNAIRE_SESSION_001', 'Questionnaire Session Load', 'Dataverse', 'dataverse_connection', 'Questionnairesession', 'Files/raw/Dataverse', '*.csv', 'FULL', 'NULL', 'NULL', 'Files/processed/Dataverse', 'Questionnairesession.csv', 'csv', 'overwrite', 'WEEKLY', 10, true,  current_timestamp(), current_timestamp(), NULL, NULL, NULL, NULL),
('CFG_OUTBOUND_REFERRAL_001', 'Outbound Referral Load', 'Dataverse', 'dataverse_connection', 'Outboundreferral', 'Files/raw/Dataverse', '*.csv', 'FULL', 'NULL', 'NULL', 'Files/processed/Dataverse', 'Outboundreferral.csv', 'csv', 'overwrite', 'WEEKLY', 13, true,  current_timestamp(),  current_timestamp(), NULL, NULL, NULL, NULL),
('CFG_IAR_DST_ASSESSMENT_001', 'IAR DST Assessment Load', 'Dataverse', 'dataverse_connection', 'IARDSTassessment', 'Files/raw/Dataverse', '*.csv', 'FULL', 'NULL', 'NULL', 'Files/processed/Dataverse', 'IARDSTassessment.csv', 'csv', 'overwrite', 'WEEKLY', 4, true, current_timestamp(), current_timestamp(), NULL, NULL, NULL, NULL),
('CFG_SERVICE_CONTACT_001', 'Service Contact Load', 'Dataverse', 'dataverse_connection', 'Servicecontact', 'Files/raw/Dataverse', '*.csv', 'FULL', 'NULL', 'NULL', 'Files/processed/Dataverse', 'Servicecontact.csv', 'csv', 'overwrite', 'WEEKLY', 6, true,  current_timestamp(),  current_timestamp(), NULL, NULL, NULL, NULL),
('CFG_COURSE_OF_LICBT_001', 'Course of LiCBT Load', 'Dataverse', 'dataverse_connection', 'CourseofLiCBT', 'Files/raw/Dataverse', '*.csv', 'FULL', NULL, NULL, 'Files/processed/Dataverse', 'CourseofLiCBT.csv', 'csv', 'overwrite', 'MONTHLY', 1, true,  current_timestamp(),  current_timestamp(), NULL, NULL, NULL, NULL),
('CFG_PRIVACY_PREFERENCES_001', 'Privacy Preferences Load', 'Dataverse', 'dataverse_connection', 'Privacypreferences', 'Files/raw/Dataverse', '*.csv', 'FULL', NULL, NULL, 'Files/processed/Dataverse', 'Privacypreferences.csv', 'csv', 'overwrite', 'WEEKLY', 13, true,  current_timestamp(),  current_timestamp(), NULL, NULL, NULL, NULL),
('CFG_OUTCOMES_001', 'Outcomes Load', 'Dataverse', 'dataverse_connection', 'Outcomes', 'Files/raw/Dataverse', '*.csv', 'FULL', 'NULL', 'NULL', 'Files/processed/Dataverse', 'Outcomes.csv', 'csv', 'overwrite', 'WEEKLY', 12, true,  current_timestamp(),  current_timestamp(), NULL, NULL, NULL, NULL),
('CFG_CLIENT_001', 'Client Load', 'Dataverse', 'dataverse_connection', 'Client', 'Files/raw/Dataverse', '*.csv', 'FULL', 'NULL', 'NULL', 'Files/processed/Dataverse', 'Client.csv', 'csv', 'overwrite', 'WEEKLY', 2, true,  current_timestamp(),  current_timestamp(), NULL, NULL, NULL, NULL),
('CFG_PRACTITIONER_001', 'Practitioner Load', 'Dataverse', 'dataverse_connection', 'Practitioner', 'Files/raw/Dataverse', '*.csv', 'FULL', NULL, NULL, 'Files/processed/Dataverse', 'Practitioner.csv', 'csv', 'overwrite', 'WEEKLY', 8, true,  current_timestamp(),  current_timestamp(), NULL, NULL, NULL, NULL),
('CFG_INTAKE_001', 'Intake Load', 'Dataverse', 'dataverse_connection', 'Intake', 'Files/raw/Dataverse', '*.csv', 'FULL', NULL, NULL, 'Files/processed/Dataverse', 'Intake.csv', 'csv', 'overwrite', 'MONTHLY', 2, true,  current_timestamp(),  current_timestamp(), NULL, NULL, NULL, NULL);
-- Out:
-- StatementMeta(, 69a8fcaf-e407-4c6a-9a0c-4860307a5aba, 13, Finished, Available, Finished, False)
-- <Spark SQL result set with 0 rows and 0 fields>
